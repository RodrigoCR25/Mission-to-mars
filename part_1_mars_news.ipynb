# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

import json
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com

url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object

html = browser.html
soup = soup(html, 'html.parser')

soup

#slide_elem = news_soup.select_one('div.list_text')
#slide_elem.find('div', class_='content_title')
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8621_sol2597_2600_mosaic-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 26, 2023</div>
# <div class="content_title">NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet</div>
# <div class="article_teaser_body">To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8721_24759_PIA23491-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 25, 2023</div>
# <div class="content_title">A New Video Captures the Science of NASA's Perseverance Mars Rover</div>
# <div class="article_teaser_body">With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8511_PIA23279-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 25, 2023</div>
# <div class="content_title">Deadline Closing for Names to Fly on NASA's Next Mars Rover</div>
# <div class="article_teaser_body">You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8707_PIA23764-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 22, 2023</div>
# <div class="content_title">7 Things to Know About the Mars 2020 Perseverance Rover Mission</div>
# <div class="article_teaser_body">NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8613_InSight-Nature-papers-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 11, 2023</div>
# <div class="content_title">A Year of Surprising Science From NASA's InSight Mars Mission</div>
# <div class="article_teaser_body">A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 10, 2023</div>
# <div class="content_title">My Culture, My Voice</div>
# <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8551_PIA23551-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 5, 2023</div>
# <div class="content_title">Mars Scientists Investigate Ancient Life in Australia</div>
# <div class="article_teaser_body">Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8631_PIA23624_hutton-selfie-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 3, 2023</div>
# <div class="content_title">NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb</div>
# <div class="article_teaser_body">Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8544_Pathfinder-Background-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 2, 2023</div>
# <div class="content_title">Screening Soon: 'The Pathfinders' Trains Lens on Mars</div>
# <div class="article_teaser_body">With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8528_PIA23376-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">January 1, 2023</div>
# <div class="content_title">HiRISE Views NASA's InSight and Curiosity on Mars</div>
# <div class="article_teaser_body">New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8724_launchscreen-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">December 30, 2022</div>
# <div class="content_title">NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet</div>
# <div class="article_teaser_body">The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8522_PIA21261-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">December 30, 2022</div>
# <div class="content_title">NASA's Curiosity Rover Finds an Ancient Oasis on Mars</div>
# <div class="article_teaser_body">New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">December 29, 2022</div>
# <div class="content_title">Robotic Toolkit Added to NASA's Mars 2020 Rover</div>
# <div class="article_teaser_body">The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8691_rover-overlay-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">December 29, 2022</div>
# <div class="content_title">While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus</div>
# <div class="article_teaser_body">This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8634_PIA23769-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">December 26, 2022</div>
# <div class="content_title">10.9 Million Names Now Aboard NASA's Perseverance Mars Rover</div>
# <div class="article_teaser_body">As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div></div></body></html>

# %%
# Extract all the text elements

titles = soup.find_all('div',class_='content_title')

a=1
for title in titles:
    print(a,".",title.text)
    a=a+1
# Out:
# 1 . NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet
# 2 . A New Video Captures the Science of NASA's Perseverance Mars Rover
# 3 . Deadline Closing for Names to Fly on NASA's Next Mars Rover
# 4 . 7 Things to Know About the Mars 2020 Perseverance Rover Mission
# 5 . A Year of Surprising Science From NASA's InSight Mars Mission
# 6 . My Culture, My Voice
# 7 . Mars Scientists Investigate Ancient Life in Australia
# 8 . NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb
# 9 . Screening Soon: 'The Pathfinders' Trains Lens on Mars
# 10 . HiRISE Views NASA's InSight and Curiosity on Mars
# 11 . NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet
# 12 . NASA's Curiosity Rover Finds an Ancient Oasis on Mars
# 13 . Robotic Toolkit Added to NASA's Mars 2020 Rover
# 14 . While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus
# 15 . 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover

# %%
summaries= soup.find_all('div', class_='article_teaser_body')

b=1
for summary in summaries:
    print(b,'.',summary.text)
    b=b+1
# Out:
# 1 . To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.
# 2 . With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.
# 3 . You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover.
# 4 . NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# 5 . A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.
# 6 . In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.
# 7 . Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# 8 . Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.
# 9 . With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.
# 10 . New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
# 11 . The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021.
# 12 . New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# 13 . The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover.
# 14 . This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.
# 15 . As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries

slide_elem = soup.find_all('div',class_='list_text')

mars_list = []

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list

for elem in slide_elem:
    mars_data={"title":"","preview":""}
    title=elem.find('div',class_='content_title').text
    summary= elem.find('div', class_='article_teaser_body').text
    mars_data["title"] = title
    mars_data["preview"] = summary
    mars_list.append(mars_data)

# %%
# Print the list to confirm success

print(mars_list)
# Out:
# [{'title': "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", 'preview': 'To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.'}, {'title': "A New Video Captures the Science of NASA's Perseverance Mars Rover", 'preview': 'With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.'}, {'title': "Deadline Closing for Names to Fly on NASA's Next Mars Rover", 'preview': 'You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. '}, {'title': '7 Things to Know About the Mars 2020 Perseverance Rover Mission', 'preview': "NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission."}, {'title': "A Year of Surprising Science From NASA's InSight Mars Mission", 'preview': "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}, {'title': 'My Culture, My Voice', 'preview': 'In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.'}, {'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}, {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}, {'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars", 'preview': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'}, {'title': "HiRISE Views NASA's InSight and Curiosity on Mars", 'preview': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'}, {'title': 'NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet', 'preview': "The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021. "}, {'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'preview': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}, {'title': "Robotic Toolkit Added to NASA's Mars 2020 Rover", 'preview': "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. "}, {'title': "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus", 'preview': "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars."}, {'title': "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover", 'preview': "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars."}]

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

json_mars = json.dumps(mars_list)
print(json_mars)
# Out:
# [{"title": "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", "preview": "To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet."}, {"title": "A New Video Captures the Science of NASA's Perseverance Mars Rover", "preview": "With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions."}, {"title": "Deadline Closing for Names to Fly on NASA's Next Mars Rover", "preview": "You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. "}, {"title": "7 Things to Know About the Mars 2020 Perseverance Rover Mission", "preview": "NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission."}, {"title": "A Year of Surprising Science From NASA's InSight Mars Mission", "preview": "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}, {"title": "My Culture, My Voice", "preview": "In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA."}, {"title": "Mars Scientists Investigate Ancient Life in Australia", "preview": "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}, {"title": "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", "preview": "Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its \"selfie stick,\" or robotic arm, in action."}, {"title": "Screening Soon: 'The Pathfinders' Trains Lens on Mars", "preview": "With the Mars 2020 mission ramping up, the documentary \u2014 the first of four about past JPL missions to the Red Planet to be shown at Caltech \u2014 tells a gripping backstory."}, {"title": "HiRISE Views NASA's InSight and Curiosity on Mars", "preview": "New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along."}, {"title": "NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet", "preview": "The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021. "}, {"title": "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", "preview": "New evidence suggests salty, shallow ponds once dotted a Martian crater \u2014 a sign of the planet's drying climate."}, {"title": "Robotic Toolkit Added to NASA's Mars 2020 Rover", "preview": "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. "}, {"title": "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus", "preview": "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars."}, {"title": "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover", "preview": "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars."}]

# %%
# Export data to MongoDB
